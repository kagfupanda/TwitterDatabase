# %%
import tweepy
import json

consumer_key="eN1MwDQ3IS9aHS2nl5eN9FhlQ"
consumer_secret="5TtkJHVmZthp7mu5kVrtKJNwd9UrN0YQ8rpAl18rXj7S2eSmiF"
access_token="4535201292-76uCkz5CzRtmccCsRYLb6JD9ODOMLlMzCDa9hsr"
access_token_secret="E57aEOipKVgmw0pPdT1yZ94o1TnckOK61k41RoX4Vb0zH"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

rest = tweepy.API(auth) # instance of rest api

    
class StdOutListener(tweepy.streaming.StreamListener):
    # A listener handles tweets that are received from the stream.
    #This listener collects N tweets, storing them in memory, and then stops.
    def __init__(self,N):
        super(StdOutListener,self).__init__(self)
        self.data = []
        self.N = N
    def on_data(self, data):
        self.data.append(json.loads(data))
        if len(self.data) >= self.N:
            return False
        else:
            return True

    def on_error(self, status):
        print(status)
        
def getNtweets(N, auth, track = [], locations = []):
    listener = StdOutListener(N)
    stream = tweepy.Stream(auth, listener)
    if len(track) and len(locations):
        stream.filter(track=track, locations = locations)
    elif len(track):
        stream.filter(track = track)
    elif len(locations):
        stream.filter(locations = locations)

    return listener.data
dataScienceTweets = getNtweets(10, auth, track=['data', 'science'])
#for tweet in dataScienceTweets:
    #print(tweet['text'])
    
bbox = [-180.00, -90, 180.00, 90]
globalTweets = getNtweets(100, auth, locations=bbox)

globalTweets[0].keys()

for tweet in globalTweets:
    print(tweet['place']['full_name'])
    print(tweet['text'])
    print("")
# Out:
# บวรนิเวศ, ประเทศไทย
# บ้าจริงดูละครซีนพระนางทำไมเรายิ้มไม่หุบเลยอ่ะ #เกมเสน่หา
#
# Duque de Caxias, Brasil
# Tempinho desse pede sexo e muita comida 😂✌️
#
# تاروت, المملكة العربية السعودية
# ٢، ٣، ٥، ٦، ٩، ١٠ هههههههههههههههههههههههههههههههههههههههههههههههههههههه https://t.co/QR2LBukjNC
#
# Zilwaukee, MI
# I have so much to get done in 34 days.
#
# Brentwood, NY
# Cleared: Construction on #SagtikosStateParkway SB at Exit S2 - Crooked Hill Road; Pilgrim Psychiatric Hospital
#
# Mississauga, Ontario
# and sweetheart I'm never going to talk to you again but that might make you understand that when I came out there 6… https://t.co/i7lr20ItiM
#
# South Lockport, NY
# Cleared: Construction on #NY93 Both directions from Beattie Avenue; CR 14 to Raymond Road
#
# Panama
# Como me gustaría que de verdad vieran la necesidad de cambiar la estructura humana de gobierno para q algo como est… https://t.co/LHIbJNKygO
#
# Kerry, Ireland
# 24 Woodview Park, Kileen, Tralee, Kerry ⇨ POA | 3 Bed Semi-Detached House 82.. | https://t.co/JAkSwRN9so | #kerry #tralee
#
# Caloocan City, National Capital Region
# @Philomenajabbar Joke lang teh ahahaaaahaha ehm sherep joke hahahahahahahah
#
# Manhattan, NY
# Cleared: Construction on #M23Bus EB at W 23rd Street:11th Avenue
#
# Fairport, NY
# Cleared: Construction on #WhitneyRoad Both directions from Turk Hill Road to Howell Road
#
# Nevada, USA
# @nicoleteresaaa  says she’ll buy you Wing Stop on Monday, at least twice a week when you see her lit LMFAO
#
# New Windsor, NY
# Cleared: Special Event on #StewartInternationalAirport
#
# Antwerpen, België
# Love for neon signs 🌌
# Model lynnharinger
# #photography #pixel_ig #visualsgang #visualoflife #justgoshoot… https://t.co/mumxp6gLi9
#
# Thung Maha Mek, Thailand
# CEO ปาร์คจินยอง! 😭
#
# New York, USA
# Cleared: Construction on #NY8 Both directions from Exit   -  NY 12 to South Main Street; NY 28
#
# Camden Town, London
# C’est vrai! https://t.co/KYNz54PfKE
#
# Cutler Bay, FL
# @Zach_FYHENT @_TBagEm @_J1W @_thatboytrent @_SlyyDoee @TpMiller305 @___Draco___ @0vo_dsean Yesterday was too easy run it back
#
# Steubenville, OH
# @emiillleee_y I love when future is featured too
#
# Rio de Janeiro, Brasil
# E dps ficar de conchinha https://t.co/DYOxLC3HF8
#
# New York, USA
# Cleared: Construction on #I90BerkshireConnector EB from After Exit B1 - Hudson - Rensselaer (US9 - I-90W) to After Exit B1 - Hudson -...
#
# Buffalo, NY
# Cleared: Closure on #NY33 EB at Exit   - Humboldt Parkway
#
# Independencia, Chile
# @Seg_Publica_Ind @Carabdechile @Muni_Indep @Duranbaronti Felicitaciones. Por favor continúen haciéndolo en todo el… https://t.co/PrAVe5X4Py
#
# Binghamton, NY
# Cleared: Construction on #I81 SB from Exit 4 - NY 7; Ramp to Exit 2E - Connector from US 11 to I-81 (Exit 2) &amp; NY 17 (Exit 75)
#
# Manhattan, NY
# Cleared: Construction on #BLine Both directions at 72nd Street Station
#
# Davie, FL
# https://t.co/xrXW8iBb6x
#
# Manchester, NY
# Cleared: Construction on #NY96 Both directions from Main Street; NY 21 to Sandhill RD
#
# Gurgaon, India
# After all the Angrezi food, it is this on my mind! Let's create more stuff, let's start doing something new!… https://t.co/oh6u5L7MED
#
# Brasília, Brazil
# https://t.co/Ar1g3FpJh5
#
# Greater Sudbury / Grand Sudbury, Ontario
# Pride Paddle!
#
# Join us 4:30 to 6pm at the Northern Water Sports Centre for the 3rd annual Pride Paddle!
#
# We'll have… https://t.co/pdYtW9aqKI
#
# New York, USA
# Cleared: Construction on #NY365 Both directions at Town of Trenton; Village of Barneveld Line
#
# Bronx, NY
# Cleared: Incident on #5Line from 149th Street-3rd Avenue Station to East 180th Street Station
#
# Al Seeb, Oman
# 😂😂😂😂😂😭😭❤️ https://t.co/cyJBRJWuli
#
# London, England
# https://t.co/NYlHQagikb please stfu 😴 leave that racist shit in America and outta football ⚽️ fake woke
#
# Texas, USA
# https://t.co/sh0dOWmOpO 👍👍 https://t.co/7RzukDqNil
#
# Punjab, Pakistan
# NAHAL MARYAM DONO KAHIN  ELKN,, 2018,, KO BHAD ME DALNE DALNE TYAR,, KE KHIN, SHABAZHMZA KOI,,OHDA NA UCHAK LE ???????????????
#
# Butuan City, Caraga
# Ang ending part sa ep15 😓😲
# Happy ending unta ni uie! #AboutTime
#
# Kentucky, USA
# Putting in those long hours https://t.co/a3YUTrJ5nj
#
# Brazil
# @GhofNTC @charadadf @sergiorj93 @ESPNEsportsBR @mibr @tarik tóxico
#
# Niagara Falls, NY
# Cleared: Construction on #LasalleExpressway EB from START ROUTE  LaSalle Expressway; I-190 to Exit   - Williams Road; Ramp
#
# New York, USA
# Cleared: Construction on #NY190 Both directions from Atwood Road to Recore Road
#
# Manhattan, NY
# Cleared: Incident on #BLine Both directions at 86th Street Station
#
# Kirkwood, NY
# Cleared: Construction on #I81 SB from Exit 3  - Broad Avenue West to Exit 2E - Connector from US 11 to I-81 (Exit 2) &amp; NY 17 (Exit 75)
#
# Cicero, NY
# Cleared: Construction on #US11 SB from Caughdenoy Road to Bear Road; CR 191
#
# North Gates, NY
# Cleared: Construction on #NY390 SB from Exit 22 - Lexington Avenue to Exit 21 - Lyell Avenue; NY 31
#
# City of Tagum, Davao Region
# @spiees @liitabasolo Sali niyo rin ako! Hahaha
#
# Milan, Lombardy
# Iscriviti al nuovo gruppo su @facebook di @SUmanitaria &gt; https://t.co/OUg2Czgm6E #Umanitaria https://t.co/Uoegpz7Dti
#
# Herculândia, Brasil
# Estou sozinho a 6 dias estou louco de vontade de chupa uma buceta quem vem
#
# New Delhi, India
# https://t.co/JUDHS9LcQc
#  Hi,
# you can read my food reviews on #Zomato #Zomato10
# They call me #superfoodie… https://t.co/GnuOBiA6Rp
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-3a7fd252156a> in <module>()
#      53
#      54 for tweet in globalTweets:
# ---> 55     print(tweet['place']['full_name'])
#      56     print(tweet['text'])
#      57     print("")
#
# KeyError: 'place'
